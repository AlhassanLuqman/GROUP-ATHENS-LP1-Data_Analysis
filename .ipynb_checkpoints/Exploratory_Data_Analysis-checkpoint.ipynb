# %% [markdown]
# # Introduction

# %% [markdown]
# We have been tasked to analyse the datasets provided (Indian Start-up Funding 2018-2021)

# %%
## Load appropriate packages
import warnings
import re
import pandas as pd
import numpy as np

# %%
#Ignoring Warnings that might arise throughout the project

warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading the 2018 Dataset and Cleaning It

# %%
#using Pandas to load the csv file needed to be cleaned

df_18 = pd.read_csv('./data/startup_funding2018.csv')

# %%
#Taking a Glimpse of the Dataset

df_18.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
#Looking at the number of rows and the number of columns in the 2018 Dataset

df_18.shape
# Out:
# (526, 6)

# %%
# Getting some statistical values from the dataset 

df_18.describe()
# Out:
#            Company Name Industry Round/Series Amount  \
# count               526      526          526    526
# unique              525      405           21    198
# top     TheCollegeFever        —         Seed      —
# freq                  2       30          280    148
#
#                            Location  \
# count                           526
# unique                           50
# top     Bangalore, Karnataka, India
# freq                            102
#
#                                             About Company
# count                                                 526
# unique                                                524
# top     TheCollegeFever is a hub for fun, fiesta and f...
# freq                                                    2

# %%
# Looking at the Column Names of the dataset

df_18.columns
# Out:
# Index(['Company Name', 'Industry', 'Round/Series', 'Amount', 'Location',
#        'About Company'],
#       dtype='object')

# %%
# The 'Location' column was in the format, 'City, Region, Country', but we needed only the 'City' aspect of the value
# Thus taking all character until we reach a comma sign

df_18["Location"] = df_18['Location'].str.split(',').str[0]

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Bengaluru

bengaluru = df_18.loc[df_18['Location'] == 'Bengaluru'].count()

# Testing whether there are any such occurence of the city Bengaluru

if(bengaluru['Location'].sum() > 0):
    
    # Replacing the all occurances of Bengaluru and Bangalore City as Bangalore
    
    df_18['Location'] = df_18['Location'].str.replace('Bengaluru','Bangalore')
    df_18['Location'] = df_18['Location'].str.replace('Bangalore City','Bangalore')

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Gurugram

gurugram = df_18.loc[df_18['Location'] == 'Gurugram'].count()

# Testing whether there are any such occurence of the city Bengaluru

if(gurugram['Location'].sum() > 0):
    
    # Replacing the all occurances of Gurugram as Gurgaon
    
    df_18['Location'] = df_18['Location'].str.replace('Gurugram','Gurgaon')

# %%
# This is for looking for columns with City New Delhi

delhi = df_18.loc[df_18['Location'] == 'New Delhi'].count()

# Testing whether there are any such occurence of the city New Delhi

if(delhi['Location'].sum() > 0):
    # Replacing the all occurances of Gurugram as Gurgaon
    
    df_18['Location'] = df_18['Location'].str.replace('New Delhi','Delhi')

# %%
# Renaming columns so that it matches with that of the other year's dataset

df_18.rename(columns = {'Company Name':'Company/Brand',
                        'Industry':'Sector',
                        'Amount':'Amount($)',
                        'Location':'HeadQuarter',
                        'About Company':'What it does'}, 
             inplace = True)

# %%
# Verifying the renaming of columns 

df_18.columns
# Out:
# Index(['Company/Brand', 'Sector', 'Round/Series', 'Amount($)', 'HeadQuarter',
#        'What it does'],
#       dtype='object')

# %%
df_18
# Out:
#          Company/Brand                                             Sector  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series    Amount($) HeadQuarter  \
# 0           Seed       250000   Bangalore
# 1           Seed  ₹40,000,000      Mumbai
# 2       Series A  ₹65,000,000     Gurgaon
# 3          Angel      2000000       Noida
# 4           Seed            —   Hyderabad
# ..           ...          ...         ...
# 521     Series C    225000000   Bangalore
# 522     Series A            —     Haryana
# 523         Seed         7500      Mumbai
# 524         Seed  ₹35,000,000      Mumbai
# 525     Series C     35000000     Chennai
#
#                                           What it does
# 0    TheCollegeFever is a hub for fun, fiesta and f...
# 1    A startup which aggregates milk from dairy far...
# 2            Leading Online Loans Marketplace in India
# 3    PayMe India is an innovative FinTech organizat...
# 4    Eunimart is a one stop solution for merchants ...
# ..                                                 ...
# 521  Udaan is a B2B trade platform, designed specif...
# 522            HappyEasyGo is an online travel domain.
# 523  Mombay is a unique opportunity for housewives ...
# 524  Droni Tech manufacture UAVs and develop softwa...
# 525       Welcome to India's most convenient pharmacy!
#
# [526 rows x 6 columns]

# %%
# Adding a new column called Funding Year, so that when the four datasets are merged later, 
# it will be easier to associate each row to its year of funding

df_18.insert(5,"Funding Year", 2018)

# %%
# Rearranging the columns to correspond to that of the 
df_18 = df_18.reindex(columns=['Company/Brand',
                               'HeadQuarter', 
                               'Sector', 
                               'What it does',
                               'Amount($)',
                               'Funding Year'])

# %%
# After careful examination, the Amount column is supposed to be in USD but there are some that in Indian Rupees (INR)

rupees = df_18[df_18["Amount($)"].str.startswith("₹")]

# Displaying all rows with the INR sign
rupees
# Out:
#        Company/Brand HeadQuarter  \
# 1    Happy Cow Dairy      Mumbai
# 2         MyLoanCare     Gurgaon
# 6          Tripshelf     Kalkaji
# 7       Hyperdata.IO   Hyderabad
# 15           Pitstop   Bangalore
# ..               ...         ...
# 513            Nykaa      Mumbai
# 514          Chaayos       Delhi
# 516         LT Foods       Delhi
# 517       Multibashi   Bangalore
# 524       Droni Tech      Mumbai
#
#                                                 Sector  \
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 6                       Internet, Leisure, Marketplace
# 7                                      Market Research
# 15         Automotive, Search Engine, Service Industry
# ..                                                 ...
# 513                          Beauty, Fashion, Wellness
# 514                Food and Beverage, Restaurants, Tea
# 516  Food and Beverage, Food Processing, Manufacturing
# 517                               E-Learning, Internet
# 524                             Information Technology
#
#                                           What it does       Amount($)  \
# 1    A startup which aggregates milk from dairy far...     ₹40,000,000
# 2            Leading Online Loans Marketplace in India     ₹65,000,000
# 6    Tripshelf is an online market place for holida...     ₹16,000,000
# 7    Hyperdata combines advanced machine learning w...     ₹50,000,000
# 15   Pitstop offers general repair and maintenance ...    ₹100,000,000
# ..                                                 ...             ...
# 513  Nykaa.com is a premier online beauty and welln...  ₹1,130,000,000
# 514  Chaayos was born in November 2012 out of this ...    ₹810,000,000
# 516  LT Foods believe that nature will continue to ...  ₹1,400,000,000
# 517                   Free language learning platform.     ₹10,000,000
# 524  Droni Tech manufacture UAVs and develop softwa...     ₹35,000,000
#
#      Funding Year
# 1            2018
# 2            2018
# 6            2018
# 7            2018
# 15           2018
# ..            ...
# 513          2018
# 514          2018
# 516          2018
# 517          2018
# 524          2018
#
# [144 rows x 6 columns]

# %%
# Since the rupee values need to be converted to USD, there is a site that gives the yearly historic exchange rate of currencies
# against the USD. 

# Downloaded the yearly historical exchange rate for the years 2018-2021 
# from https://data.oecd.org/conversion/exchange-rates.htm 

# Loading the yearly historical exchange rate for the years 2018-2021

exchange_rate = pd.read_csv('./data/historic_exchange_rate.csv')

# Displaying the values from the .csv

exchange_rate
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME       Value  Flag Codes
# 0        AUS      EXCH     TOT  NATUSD         A  2018    1.338412         NaN
# 1        AUS      EXCH     TOT  NATUSD         A  2019    1.438507         NaN
# 2        AUS      EXCH     TOT  NATUSD         A  2020    1.453085         NaN
# 3        AUS      EXCH     TOT  NATUSD         A  2021    1.331224         NaN
# 4        AUT      EXCH     TOT  NATUSD         A  2018    0.846773         NaN
# ..       ...       ...     ...     ...       ...   ...         ...         ...
# 251      CMR      EXCH     TOT  NATUSD         A  2021  554.530675         NaN
# 252      SEN      EXCH     TOT  NATUSD         A  2018  555.446458         NaN
# 253      SEN      EXCH     TOT  NATUSD         A  2019  585.911013         NaN
# 254      SEN      EXCH     TOT  NATUSD         A  2020  575.586005         NaN
# 255      SEN      EXCH     TOT  NATUSD         A  2021  554.530675         NaN
#
# [256 rows x 8 columns]

# %%
# Filtering for the dataset concerning India

indian_usd_rate = exchange_rate.loc[exchange_rate['LOCATION'] == 'IND']

# Displaying rows for INR/USD yearly exchange rate for the years 2018-2021

indian_usd_rate
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value  Flag Codes
# 140      IND      EXCH     TOT  NATUSD         A  2018  68.389467         NaN
# 141      IND      EXCH     TOT  NATUSD         A  2019  70.420341         NaN
# 142      IND      EXCH     TOT  NATUSD         A  2020  74.099567         NaN
# 143      IND      EXCH     TOT  NATUSD         A  2021  73.918013         NaN

# %%
# Selecting specifically the value for the exchange rate between INR and USD for the year 2018

value = exchange_rate.query("LOCATION == 'IND' and TIME == 2018")

# %%
# Converting value returned into a float for currency conversion later on

rate_value = float(value['Value'])

# %%
# Creating a column that would be used as a temporary holding column to help indicate whether a value on the Amount($) column 
# is in INR, USD or -

df_18['Amount(USD)'] = ''

# %%
# If the Amount($) starts with ₹, it would be represented by the 'R' on the newly created column
df_18.loc[df_18['Amount($)'].str.startswith("₹"), 'Amount(USD)'] = 'R'

# If the Amount($) starts with $, it would be represented by the 'U' on the newly created column
df_18.loc[df_18['Amount($)'].str.startswith("$"), 'Amount(USD)'] = 'U'

# If the Amount($) is —, it would be represented by the 'E' on the newly created column
df_18.loc[df_18['Amount($)'] == "—", 'Amount(USD)'] = 'E'

# %%
# Striping off the values in Amount($), the currency signs (₹ and $)

df_18.loc[df_18['Amount($)'].str.startswith("₹"), 'Amount($)'] = df_18['Amount($)'].str[1:]
df_18.loc[df_18['Amount($)'].str.startswith("$"), 'Amount($)'] = df_18['Amount($)'].str[1:]

# Assigning 1.0 to the rows that have "-" as value

df_18.loc[df_18['Amount($)'].str.startswith("—"), 'Amount($)'] = '1.0'

# %%
# Removing all commas from the values of Amount($)

df_18.loc[df_18['Amount($)'].str.contains(',', regex=True), 'Amount($)'] = df_18['Amount($)'].str.replace(',','')

# %%
# Now that the Amount($) is void of any non numerical characters, Converting the column to a float

df_18['Amount($)'] = df_18['Amount($)'].astype(float)

# %%
# Selecting all amount that had the INR sign on them to its USD equivalence using the value from the yearly historic exchange
# rate, making reference to the Amount(USD) table that was created above

df_18.loc[df_18['Amount(USD)'] == 'R', 'Amount($)'] = df_18['Amount($)'] / rate_value

# %%
# Dropping the temporal column created to make reference to those row that had other currencies other than USD

df_18.drop(columns=['Amount(USD)'], inplace=True)

# %%
# A preview of the cleaned dataset for 2018

df_18
# Out:
#          Company/Brand HeadQuarter  \
# 0      TheCollegeFever   Bangalore
# 1      Happy Cow Dairy      Mumbai
# 2           MyLoanCare     Gurgaon
# 3          PayMe India       Noida
# 4             Eunimart   Hyderabad
# ..                 ...         ...
# 521              Udaan   Bangalore
# 522  Happyeasygo Group     Haryana
# 523             Mombay      Mumbai
# 524         Droni Tech      Mumbai
# 525            Netmeds     Chennai
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What it does     Amount($)  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...  2.500000e+05
# 1    A startup which aggregates milk from dairy far...  5.848854e+05
# 2            Leading Online Loans Marketplace in India  9.504388e+05
# 3    PayMe India is an innovative FinTech organizat...  2.000000e+06
# 4    Eunimart is a one stop solution for merchants ...  1.000000e+00
# ..                                                 ...           ...
# 521  Udaan is a B2B trade platform, designed specif...  2.250000e+08
# 522            HappyEasyGo is an online travel domain.  1.000000e+00
# 523  Mombay is a unique opportunity for housewives ...  7.500000e+03
# 524  Droni Tech manufacture UAVs and develop softwa...  5.117747e+05
# 525       Welcome to India's most convenient pharmacy!  3.500000e+07
#
#      Funding Year
# 0            2018
# 1            2018
# 2            2018
# 3            2018
# 4            2018
# ..            ...
# 521          2018
# 522          2018
# 523          2018
# 524          2018
# 525          2018
#
# [526 rows x 6 columns]

# %%
# Saving the cleaned dataset as prepped_2018.csv. Waiting for other members assigned to the other year's dataset
# So that it would be merged

df_18.to_csv('./data/prepped_2018.csv', index=False)

# %% [markdown]
# ### Loading the 2020 Dataset and Cleaning It

# %%
#using Pandas to load the csv file needed to be cleaned

df_20 = pd.read_csv('./data/startup_funding2020.csv')

# %%
#Taking a Glimpse of the Dataset

df_20
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu     NaN       Delhi              Edtech
# 1051         EpiFi     NaN         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor    Amount($)       Stage  \
# 0                           Angel investors     $200,000         NaN
# 1                           GSF Accelerator     $100,000    Pre-seed
# 2                            Venture Center  Undisclosed    Pre-seed
# 3       Venture Catalysts, PointOne Capital     $400,000         NaN
# 4       Siana Capital Management, Info Edge     $340,000         NaN
# ...                                     ...          ...         ...
# 1050  DSG Consumer Partners, Blume Ventures   $1,500,000         NaN
# 1051          Sequoia India, Ribbit Capital  $13,200,000  Seed Round
# 1052                             Verlinvest   $8,000,000         NaN
# 1053             SIG Global India Fund LLP.   $8,043,000    Series C
# 1054                      Chiratae Ventures   $9,000,000    Series A
#
#      Unnamed: 9
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1050        NaN
# 1051        NaN
# 1052        NaN
# 1053        NaN
# 1054        NaN
#
# [1055 rows x 10 columns]

# %%
# Looking at the Column Names of the dataset

df_20.columns
# Out:
# Index(['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'Unnamed: 9'],
#       dtype='object')

# %%
# Droping the columns that are not important to our analysis including an unnamed column

df_20.drop(columns=df_20.columns[[1,5,6,8,-1]],  axis=1,  inplace=True)

# %%
# Adding a new column called Funding Year, so that when the four datasets are merged later, 
# it will be easier to associate each row to its year of funding

df_20.insert(5,"Funding Year", 2020)

# %%
# Verifying the dataset

df_20
# Out:
#      Company/Brand HeadQuarter              Sector  \
# 0       Aqgromalin     Chennai            AgriTech
# 1         Krayonnz   Bangalore              EdTech
# 2     PadCare Labs        Pune  Hygiene management
# 3            NCOME       Delhi              Escrow
# 4       Gramophone      Indore            AgriTech
# ...            ...         ...                 ...
# 1050  Leverage Edu       Delhi              Edtech
# 1051         EpiFi         NaN             Fintech
# 1052       Purplle      Mumbai           Cosmetics
# 1053        Shuttl       Delhi           Transport
# 1054         Pando     Chennai            Logitech
#
#                                            What it does    Amount($)  \
# 0                          Cultivating Ideas for Profit     $200,000
# 1     An academy-guardian-scholar centric ecosystem ...     $100,000
# 2      Converting bio-hazardous waste to harmless waste  Undisclosed
# 3                          Escrow-as-a-service platform     $400,000
# 4     Gramophone is an AgTech platform enabling acce...     $340,000
# ...                                                 ...          ...
# 1050  AI enabled marketplace that provides career gu...   $1,500,000
# 1051  It offers customers with a single interface fo...  $13,200,000
# 1052         Online makeup and beauty products retailer   $8,000,000
# 1053                    App based bus aggregator serice   $8,043,000
# 1054            Networked logistics management software   $9,000,000
#
#       Funding Year
# 0             2020
# 1             2020
# 2             2020
# 3             2020
# 4             2020
# ...            ...
# 1050          2020
# 1051          2020
# 1052          2020
# 1053          2020
# 1054          2020
#
# [1055 rows x 6 columns]

# %%
# The 'Location' column was in the format, 'City, Region, Country', but we needed only the 'City' aspect of the value
# Thus taking all character until we reach a comma sign

df_20["HeadQuarter"] = df_20['HeadQuarter'].str.split(',').str[0]

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Gurugram

gurugram = df_20.loc[df_20['HeadQuarter'] == 'Gurugram'].count()

# Testing whether there are any such occurence of the city Gurugram

if(gurugram['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of Gurugram as Gurgaon
    df_20['HeadQuarter'] = df_20['HeadQuarter'].str.replace('Gurugram','Gurgaon')

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Bengaluru

bengaluru = df_20.loc[(df_20['HeadQuarter'] == 'Bengaluru')].count()

# Testing whether there are any such occurence of the city Bengaluru

if(bengaluru['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of Bengaluru and Bangalore City as Bangalore
    
    df_20['HeadQuarter'] = df_20['HeadQuarter'].str.replace('Bengaluru','Bangalore')
    df_20['HeadQuarter'] = df_20['HeadQuarter'].str.replace('Bangalore City','Bangalore')
    df_20['HeadQuarter'] = df_20['HeadQuarter'].str.replace('Banglore','Bangalore')

# %%
# This is for looking for columns with City New Delhi

delhi = df_20.loc[df_20['HeadQuarter'] == 'New Delhi'].count()

# Testing whether there are any such occurence of the city New Delhi

if(delhi['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of New Delhi as Delhi
    
    df_20['HeadQuarter'] = df_20['HeadQuarter'].str.replace('New Delhi','Delhi')

# %%
# Replacing a wrongly spelt Hyderabad

df_20.loc[df_20['HeadQuarter'] == 'Hyderebad', 'HeadQuarter'] = 'Hyderabad'

# %%
df_20[df_20['Amount($)'].isna()]
# Out:
#         Company/Brand HeadQuarter              Sector  \
# 29          Delhivery     Gurgaon          E-commerce
# 44   PointOne Capital   Bangalore  Venture capitalist
# 235             Tring      Mumbai        Social Media
#
#                                           What it does Amount($)  Funding Year
# 29   Delhivery is a supply chain services company t...       NaN          2020
# 44                  Pre-seed/Seed focussed VC investor       NaN          2020
# 235  Tring is a celebrity engagement platform, for ...       NaN          2020

# %%
# Dropping these rows with null values as it becomes impossible to the run subsequent process

df_20 = df_20[df_20['Amount($)'].notna()]

# %%
# Striping off the values in Amount($), the $ currency sign
df_20.loc[df_20['Amount($)'].str.startswith('$'), 'Amount($)'] = df_20['Amount($)'].str[1:]

# Removing all commas from the values of Amount($)
df_20.loc[df_20['Amount($)'].str.contains(',', regex=True), 'Amount($)'] = df_20['Amount($)'].str.replace(',','')

# There was a funding but it was stated as a range, the average of the range was used
df_20.loc[df_20['Amount($)'] == '800000000 to $850000000', 'Amount($)'] = '825000000'

# Assigning all undisclosed amount as 1.0, since there was a funding, it was just not disclosed
# and also taking care of those Undisclosed values that were wrongly spelt
df_20.loc[(df_20['Amount($)'] == 'Undiclsosed') 
          | (df_20['Amount($)'] == 'Undislosed')
          | (df_20['Amount($)'] == 'Undisclosed'), 'Amount($)'] = '1.0'

# Assigning the value 28 million as verified from the site:
# https://techcrunch.com/2020/11/18/payments-app-true-balance-raises-28-million-to-reach-more-underbanked-users-in-india/
df_20.at[465, 'Amount($)'] = '28000000'

# %%
# Converting the column Amonut($) to float data type

df_20['Amount($)'] = df_20['Amount($)'].astype(float)

# %%
# Saving the cleaned dataset as prepped_2018.csv. Waiting for other members assigned to the other year's dataset
# So that it would be merged

df_20.to_csv('./data/prepped_2020.csv', index=False)

# %% [markdown]
# ### Loading the 2019 Dataset and Cleaning It

# %%
# sing Pandas to load the csv file needed to be cleaned

df_19 = pd.read_csv('./data/startup_funding2019.csv')

# %%
#Taking a Glimpse of the Dataset

df_19
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 0                                  Shantanu Deshpande
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor     Amount($)  \
# 0                                Sixth Sense Ventures    $6,300,000
# 1                                    General Atlantic  $150,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4            Innovation in Food and Agriculture (IFA)    $6,000,000
# ..                                                ...           ...
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   $20,000,000
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000
# 86                                    Sequoia Capital    $5,000,000
# 87  Norwest Venture Partners, General Catalyst, Fu...   $50,000,000
# 88     TPG, Norwest Venture Partners, Evolvence India   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 9 columns]

# %%
# Droping the columns that are not important to our analysis including an unnamed column

df_19.drop(columns=['Founded','Founders','Investor','Stage'], inplace=True)

# %%
# Adding a new column called Funding Year, so that when the four datasets are merged later, 
# it will be easier to associate each row to its year of funding

df_19.insert(5,"Funding Year", 2019)

# %%
# Verifying the dataset

df_19
# Out:
#       Company/Brand HeadQuarter                   Sector  \
# 0    Bombay Shaving         NaN                Ecommerce
# 1         Ruangguru      Mumbai                   Edtech
# 2          Eduisfun      Mumbai                   Edtech
# 3          HomeLane     Chennai          Interior design
# 4          Nu Genes   Telangana                 AgriTech
# ..              ...         ...                      ...
# 84     Infra.Market      Mumbai                Infratech
# 85              Oyo    Gurugram              Hospitality
# 86       GoMechanic       Delhi  Automobile & Technology
# 87           Spinny       Delhi               Automobile
# 88  Ess Kay Fincorp   Rajasthan                  Banking
#
#                                          What it does     Amount($)  \
# 0          Provides a range of male grooming products    $6,300,000
# 1   A learning platform that provides topic-based ...  $150,000,000
# 2             It aims to make learning fun via games.   $28,000,000
# 3               Provides interior designing solutions   $30,000,000
# 4   It is a seed company engaged in production, pr...    $6,000,000
# ..                                                ...           ...
# 84  It connects client requirements to their suppl...   $20,000,000
# 85                Provides rooms for comfortable stay  $693,000,000
# 86  Find automobile repair and maintenance service...    $5,000,000
# 87                                Online car retailer   $50,000,000
# 88              Organised Non-Banking Finance Company   $33,000,000
#
#     Funding Year
# 0           2019
# 1           2019
# 2           2019
# 3           2019
# 4           2019
# ..           ...
# 84          2019
# 85          2019
# 86          2019
# 87          2019
# 88          2019
#
# [89 rows x 6 columns]

# %%
# The 'Location' column was in the format, 'City, Region, Country', but we needed only the 'City' aspect of the value
# Thus taking all character until we reach a comma sign

df_19["HeadQuarter"] = df_19['HeadQuarter'].str.split(',').str[0]

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Gurugram

gurugram = df_19.loc[df_19['HeadQuarter'] == 'Gurugram'].count()

# Testing whether there are any such occurence of the city Gurugram

if(gurugram['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of Gurugram as Gurgaon
    df_19['HeadQuarter'] = df_19['HeadQuarter'].str.replace('Gurugram','Gurgaon')

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Bengaluru

bengaluru = df_19.loc[(df_19['HeadQuarter'] == 'Bengaluru')].count()

# Testing whether there are any such occurence of the city Bengaluru

if(bengaluru['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of Bengaluru and Bangalore City as Bangalore
    df_19['HeadQuarter'] = df_19['HeadQuarter'].str.replace('Bengaluru','Bangalore')
    df_19['HeadQuarter'] = df_19['HeadQuarter'].str.replace('Bangalore City','Bangalore')

# %%
# This is for looking for columns with City New Delhi

delhi = df_19.loc[df_19['HeadQuarter'] == 'New Delhi'].count()

# Testing whether there are any such occurence of the city New Delhi

if(delhi['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of New Delhi as Delhi
    
    df_19['HeadQuarter'] = df_18['HeadQuarter'].str.replace('New Delhi','Delhi')

# %%
# Striping off the values in Amount($), the $ currency sign
df_19.loc[df_19['Amount($)'].str.startswith('$'), 'Amount($)'] = df_19['Amount($)'].str[1:]

# Assigning all undisclosed amount as 1.0, since there was a funding, it was just not disclosed
df_19.loc[df_19['Amount($)'] == 'Undisclosed', 'Amount($)'] = '1.0'

# Removing all commas from the values of Amount($)
df_19.loc[df_19['Amount($)'].str.contains(',', regex=True), 'Amount($)'] = df_19['Amount($)'].str.replace(',','')

# %%
#Verifying changes made to dataset
df_19
# Out:
#       Company/Brand HeadQuarter                   Sector  \
# 0    Bombay Shaving   Bangalore                Ecommerce
# 1         Ruangguru      Mumbai                   Edtech
# 2          Eduisfun     Gurgaon                   Edtech
# 3          HomeLane       Noida          Interior design
# 4          Nu Genes   Hyderabad                 AgriTech
# ..              ...         ...                      ...
# 84     Infra.Market     Haryana                Infratech
# 85              Oyo   Bangalore              Hospitality
# 86       GoMechanic        Pune  Automobile & Technology
# 87           Spinny   Bangalore               Automobile
# 88  Ess Kay Fincorp       Noida                  Banking
#
#                                          What it does  Amount($)  Funding Year
# 0          Provides a range of male grooming products    6300000          2019
# 1   A learning platform that provides topic-based ...  150000000          2019
# 2             It aims to make learning fun via games.   28000000          2019
# 3               Provides interior designing solutions   30000000          2019
# 4   It is a seed company engaged in production, pr...    6000000          2019
# ..                                                ...        ...           ...
# 84  It connects client requirements to their suppl...   20000000          2019
# 85                Provides rooms for comfortable stay  693000000          2019
# 86  Find automobile repair and maintenance service...    5000000          2019
# 87                                Online car retailer   50000000          2019
# 88              Organised Non-Banking Finance Company   33000000          2019
#
# [89 rows x 6 columns]

# %%
# Converting the column Amonut($) to float data type

df_19['Amount($)'] = df_19['Amount($)'].astype(float)

# %%
# Saving the cleaned dataset as prepped_2019.csv. Waiting for other members assigned to the other year's dataset
# So that it would be merged

df_19.to_csv('./data/prepped_2019.csv', index=False)

# %% [markdown]
# ### Loading the 2021 Dataset and Cleaning It

# %%
#using Pandas to load the csv file needed to be cleaned

df_21 = pd.read_csv('./data/startup_funding2021.csv')

# %%
#Taking a Glimpse of the Dataset

df_21
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor     Amount($)  \
# 0                       BEENEXT, Entrepreneur First    $1,200,000
# 1          Unilazer Ventures, IIFL Asset Management  $120,000,000
# 2                  GSV Ventures, Westbridge Capital   $30,000,000
# 3                            CDC Group, IDG Capital   $51,000,000
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000
# ...                                             ...           ...
# 1204                                Endiya Partners      $3000000
# 1205                                       IIFL AMC     $20000000
# 1206                                   Owl Ventures     $55000000
# 1207               Winter Capital, ETS, Man Capital     $26000000
# 1208                 3one4 Capital, Kalaari Capital      $8000000
#
#              Stage
# 0     Pre-series A
# 1              NaN
# 2         Series D
# 3         Series C
# 4             Seed
# ...            ...
# 1204  Pre-series A
# 1205      Series D
# 1206      Series C
# 1207      Series B
# 1208      Series A
#
# [1209 rows x 9 columns]

# %%
# Looking at the Column Names of the dataset

df_21.columns
# Out:
# Index(['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage'],
#       dtype='object')

# %%
# Droping the columns that are not important to our analysis including an unnamed column

df_21.drop(columns=df_21.columns[[1,5,6,8]],  axis=1,  inplace=True)

# %%
# Adding a new column called Funding Year, so that when the four datasets are merged later, 
# it will be easier to associate each row to its year of funding

df_21.insert(5,"Funding Year", 2021)

# %%
# Verifying the dataset

df_21
# Out:
#        Company/Brand HeadQuarter                 Sector  \
# 0     Unbox Robotics   Bangalore             AI startup
# 1             upGrad      Mumbai                 EdTech
# 2        Lead School      Mumbai                 EdTech
# 3            Bizongo      Mumbai         B2B E-commerce
# 4           FypMoney    Gurugram                FinTech
# ...              ...         ...                    ...
# 1204        Gigforce    Gurugram  Staffing & Recruiting
# 1205          Vahdam   New Delhi       Food & Beverages
# 1206    Leap Finance   Bangalore     Financial Services
# 1207    CollegeDekho    Gurugram                 EdTech
# 1208          WeRize   Bangalore     Financial Services
#
#                                            What it does     Amount($)  \
# 0     Unbox Robotics builds on-demand AI-driven ware...    $1,200,000
# 1        UpGrad is an online higher education platform.  $120,000,000
# 2     LEAD School offers technology based school tra...   $30,000,000
# 3     Bizongo is a business-to-business online marke...   $51,000,000
# 4     FypMoney is Digital NEO Bank for Teenagers, em...    $2,000,000
# ...                                                 ...           ...
# 1204                  A gig/on-demand staffing company.      $3000000
# 1205  VAHDAM is among the world’s first vertically i...     $20000000
# 1206  International education loans for high potenti...     $55000000
# 1207  Collegedekho.com is Student’s Partner, Friend ...     $26000000
# 1208  India’s first socially distributed full stack ...      $8000000
#
#       Funding Year
# 0             2021
# 1             2021
# 2             2021
# 3             2021
# 4             2021
# ...            ...
# 1204          2021
# 1205          2021
# 1206          2021
# 1207          2021
# 1208          2021
#
# [1209 rows x 6 columns]

# %%
# The 'Location' column was in the format, 'City, Region, Country', but we needed only the 'City' aspect of the value
# Thus taking all character until we reach a comma sign

df_21["HeadQuarter"] = df_21['HeadQuarter'].str.split(',').str[0]

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Gurugram

gurugram = df_21.loc[df_21['HeadQuarter'] == 'Gurugram'].count()

# Testing whether there are any such occurence of the city Gurugram

if(gurugram['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of Gurugram as Gurgaon
    df_21['HeadQuarter'] = df_21['HeadQuarter'].str.replace('Gurugram','Gurgaon')

# %%
# From obersavtion: One notes the use of official and unofficial names of certain cities, which when not rectified
# will not give actual figures relating to a city with such perculiarity. A city with more than one name.

# This is for looking for columns with City Bengaluru

bengaluru = df_21.loc[(df_21['HeadQuarter'] == 'Bengaluru')].count()

# Testing whether there are any such occurence of the city Bengaluru

if(bengaluru['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of Bengaluru and Bangalore City as Bangalore
    df_21['HeadQuarter'] = df_21['HeadQuarter'].str.replace('Bengaluru','Bangalore')
    df_21['HeadQuarter'] = df_21['HeadQuarter'].str.replace('Bangalore City','Bangalore')

# %%
# This is for looking for columns with City New Delhi

delhi = df_21.loc[df_21['HeadQuarter'] == 'New Delhi'].count()

# Testing whether there are any such occurence of the city New Delhi

if(delhi['HeadQuarter'].sum() > 0):
    # Replacing the all occurances of New Delhi as Delhi
    df_21['HeadQuarter'] = df_21['HeadQuarter'].str.replace('New Delhi','Delhi')

# %%
#Checking for null values

df_21[df_21['Amount($)'].isna()]
# Out:
#      Company/Brand          HeadQuarter  \
# 86        Onsurity            Bangalore
# 674   MYRE Capital               Mumbai
# 1100      Sochcast  Online Media\t#REF!
#
#                                                  Sector  \
# 86                                           HealthCare
# 674                              Commercial Real Estate
# 1100  Sochcast is an Audio experiences company that ...
#
#                                            What it does Amount($)  \
# 86    Onsurity is an employee healthcare platform pr...       NaN
# 674                 Democratising Real Estate Ownership       NaN
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...       NaN
#
#       Funding Year
# 86            2021
# 674           2021
# 1100          2021

# %%
# Dropping these rows with null values as it becomes impossible to the run subsequent process

df_21 = df_21[df_21['Amount($)'].notna()]

# %%
# Striping off the values in Amount($), those starting with $$ currency sign
df_21.loc[df_21['Amount($)'].str.startswith('$$'), 'Amount($)'] = df_21['Amount($)'].str[1:]

# Striping off the values in Amount($), the $ currency sign
df_21.loc[df_21['Amount($)'].str.startswith('$'), 'Amount($)'] = df_21['Amount($)'].str[1:]

# Removing all commas from the values of Amount($)
df_21.loc[df_21['Amount($)'].str.contains(',', regex=True), 'Amount($)'] = df_21['Amount($)'].str.replace(',','')

# Assigning all undisclosed amount as 1.0, since there was a funding, it was just not disclosed
# and also taking care of those Undisclosed values that were uniquely spelt
df_21.loc[(df_21['Amount($)'] == 'Undisclosed')
        | (df_21['Amount($)'] == 'undisclosed'), 'Amount($)'] = '1.0'

# %%
# Replacing empty space with null the Amount($) column 
df_21.loc[df_21['Amount($)'].str.contains(' ', regex=True), 'Amount($)'] = df_21['Amount($)'].str.replace(' ','')

# Treating null values as undisclosed amount thus assigning them 1.0 per our convention
df_21.loc[(df_21['Amount($)'] == ''), 'Amount($)'] = '1.0'

# Rectifying the values that had other characters other than figures
df_21['Amount($)']=[re.sub('[^\w\s]+', '', s) for s in df_21['Amount($)'].tolist()]

# %%
df_21.drop(df_21[(df_21['Amount($)'].str.isalpha())].index , inplace=True)

# %%
#df_21.loc[df_21['Amount($)'] == '']
#df_21.drop([1137,1146] , inplace=True)

# %%
# Converting the Amount($) as a float data type

df_21['Amount($)'] = df_21['Amount($)'].astype(float)

# %%
#Verifying the changes made to the dataset

df_21
# Out:
#        Company/Brand HeadQuarter                 Sector  \
# 0     Unbox Robotics   Bangalore             AI startup
# 1             upGrad      Mumbai                 EdTech
# 2        Lead School      Mumbai                 EdTech
# 3            Bizongo      Mumbai         B2B E-commerce
# 4           FypMoney     Gurgaon                FinTech
# ...              ...         ...                    ...
# 1204        Gigforce     Gurgaon  Staffing & Recruiting
# 1205          Vahdam   New Delhi       Food & Beverages
# 1206    Leap Finance   Bangalore     Financial Services
# 1207    CollegeDekho     Gurgaon                 EdTech
# 1208          WeRize   Bangalore     Financial Services
#
#                                            What it does    Amount($)  \
# 0     Unbox Robotics builds on-demand AI-driven ware...    1200000.0
# 1        UpGrad is an online higher education platform.  120000000.0
# 2     LEAD School offers technology based school tra...   30000000.0
# 3     Bizongo is a business-to-business online marke...   51000000.0
# 4     FypMoney is Digital NEO Bank for Teenagers, em...    2000000.0
# ...                                                 ...          ...
# 1204                  A gig/on-demand staffing company.    3000000.0
# 1205  VAHDAM is among the world’s first vertically i...   20000000.0
# 1206  International education loans for high potenti...   55000000.0
# 1207  Collegedekho.com is Student’s Partner, Friend ...   26000000.0
# 1208  India’s first socially distributed full stack ...    8000000.0
#
#       Funding Year
# 0             2021
# 1             2021
# 2             2021
# 3             2021
# 4             2021
# ...            ...
# 1204          2021
# 1205          2021
# 1206          2021
# 1207          2021
# 1208          2021
#
# [1196 rows x 6 columns]

# %%
# Saving the cleaned dataset as prepped_2019.csv. Waiting for other members assigned to the other year's dataset
# So that it would be merged

df_21.to_csv('./data/prepped_2021.csv', index=False)

# %% [markdown]
# ### Merging the Prepped Datasets

# %%
# Declaring dataframes to read the prepped csv from above

# Laoding prepped 2018 dataset
df1 = pd.read_csv('./data/prepped_2018.csv')
# Laoding prepped 2019 dataset
df2 = pd.read_csv('./data/prepped_2019.csv')
# Laoding prepped 2020 dataset
df3 = pd.read_csv('./data/prepped_2020.csv')
# Laoding prepped 2021 dataset
df4 = pd.read_csv('./data/prepped_2021.csv')

# %%
dataset = [df1,df2,df3,df4]

# Merging the prepped datasets into a merged dataframe
merged_data = pd.concat(dataset, ignore_index=True)

# %%
# Peeking at the merged data

merged_data
# Out:
#         Company/Brand HeadQuarter  \
# 0     TheCollegeFever   Bangalore
# 1     Happy Cow Dairy      Mumbai
# 2          MyLoanCare     Gurgaon
# 3         PayMe India       Noida
# 4            Eunimart   Hyderabad
# ...               ...         ...
# 2858         Gigforce     Gurgaon
# 2859           Vahdam   New Delhi
# 2860     Leap Finance   Bangalore
# 2861     CollegeDekho     Gurgaon
# 2862           WeRize   Bangalore
#
#                                                  Sector  \
# 0     Brand Marketing, Event Promotion, Marketing, S...
# 1                                  Agriculture, Farming
# 2      Credit, Financial Services, Lending, Marketplace
# 3                           Financial Services, FinTech
# 4                    E-Commerce Platforms, Retail, SaaS
# ...                                                 ...
# 2858                              Staffing & Recruiting
# 2859                                   Food & Beverages
# 2860                                 Financial Services
# 2861                                             EdTech
# 2862                                 Financial Services
#
#                                            What it does     Amount($)  \
# 0     TheCollegeFever is a hub for fun, fiesta and f...  2.500000e+05
# 1     A startup which aggregates milk from dairy far...  5.848854e+05
# 2             Leading Online Loans Marketplace in India  9.504388e+05
# 3     PayMe India is an innovative FinTech organizat...  2.000000e+06
# 4     Eunimart is a one stop solution for merchants ...  1.000000e+00
# ...                                                 ...           ...
# 2858                  A gig/on-demand staffing company.  3.000000e+06
# 2859  VAHDAM is among the world’s first vertically i...  2.000000e+07
# 2860  International education loans for high potenti...  5.500000e+07
# 2861  Collegedekho.com is Student’s Partner, Friend ...  2.600000e+07
# 2862  India’s first socially distributed full stack ...  8.000000e+06
#
#       Funding Year
# 0             2018
# 1             2018
# 2             2018
# 3             2018
# 4             2018
# ...            ...
# 2858          2021
# 2859          2021
# 2860          2021
# 2861          2021
# 2862          2021
#
# [2863 rows x 6 columns]

# %%
# Saving the merged data in another csv

merged_data.to_csv('./data/merged_dataset.csv', index=False)

# %%
merged_data.isnull().sum()
# Out:
# Company/Brand     0
# HeadQuarter      95
# Sector           18
# What it does      0
# Amount($)         0
# Funding Year      0
# dtype: int64

# %%
merged_data.dropna(subset=['HeadQuarter','Sector'], inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# What it does     0
# Amount($)        0
# Funding Year     0
# dtype: int64

# %%
merged_data['Sector'].unique()
